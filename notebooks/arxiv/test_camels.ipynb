# %%
import h5py as h5

# %%
fname = '/mnt/ceph/users/camels/PUBLIC_RELEASE/Caesar/IllustrisTNG/L25n256/CV/CV_0/caesar_newsnaps_090.hdf5'
df = h5.File(fname, 'r')
# print(df.keys())
print(df['galaxy_data'].keys())
# print(df['galaxy_data']['sfr'])
# Out:
# <KeysViewHDF5 ['GroupID', 'bh_fedd', 'bhlist_end', 'bhlist_start', 'bhmdot', 'central', 'cloud_index_list_end', 'cloud_index_list_start', 'dicts', 'glist_end', 'glist_start', 'lists', 'minpotpos', 'minpotvel', 'nbh', 'ndm', 'ndm2', 'ndm3', 'ndust', 'ngas', 'nstar', 'parent_halo_index', 'pos', 'sfr', 'sfr_100', 'slist_end', 'slist_start', 'vel']>

# %%
# Out:
# <HDF5 dataset "absmag.sdss_i": shape (520,), type "<f8">

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as pl

# %%
pl.figure()
_ = pl.hist(df['galaxy_data']['dicts']['absmag.sdss_i'], bins=100, histtype='step', color='k')
